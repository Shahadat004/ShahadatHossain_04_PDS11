# %%
import random
import pandas as pd

files1 = {
    'Registration Number': [f'202500{i:02d}' for i in range(1, 51)],
     'Name': [f'Student_{i}' for i in range(1, 51)],
     'TT-1 Marks': [random.randint(5, 20) for _ in range(50)]
    }
df1 = pd.DataFrame(files1)

files2 = {
    'Registration Number': [f'202500{i:02d}' for i in range(1, 51)],
     'Name': [f'Student_{i}' for i in range(1, 51)],
     'TT-2 Marks': [random.randint(5, 20) for _ in range(50)]
    }
df2 = pd.DataFrame(files2)

# %%
merged_df = pd.merge(df1, df2, on=['Registration Number', 'Name'])

merged_df
# Out:
#    Registration Number        Name  TT-1 Marks  TT-2 Marks
# 0             20250001   Student_1          13          17
# 1             20250002   Student_2          17          14
# 2             20250003   Student_3          15          20
# 3             20250004   Student_4          19          17
# 4             20250005   Student_5           8           5
# 5             20250006   Student_6           6           7
# 6             20250007   Student_7          19           9
# 7             20250008   Student_8           9           9
# 8             20250009   Student_9          10           6
# 9             20250010  Student_10          10          11
# 10            20250011  Student_11           7          16
# 11            20250012  Student_12          19           7
# 12            20250013  Student_13          12          13
# 13            20250014  Student_14          20          18
# 14            20250015  Student_15           5          19
# ...

# %%
merged_df['Best Term Test Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)

merged_df['Average Term Test Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)

# Display the updated DataFrame
print(merged_df.head())
# Out:
#   Registration Number       Name  TT-1 Marks  TT-2 Marks  \
# 0            20250001  Student_1          13          17
# 1            20250002  Student_2          17          14
# 2            20250003  Student_3          15          20
# 3            20250004  Student_4          19          17
# 4            20250005  Student_5           8           5
#
#    Best Term Test Marks  Average Term Test Marks
# 0                    17                     15.0
# 1                    17                     15.5
# 2                    20                     17.5
# 3                    19                     18.0
# 4                     8                      6.5

# %%
merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])

# Display the updated DataFrame
print(merged_df.head())
# Out:
#   Registration Number       Name  Best Term Test Marks  \
# 0            20250001  Student_1                    17
# 1            20250002  Student_2                    17
# 2            20250003  Student_3                    20
# 3            20250004  Student_4                    19
# 4            20250005  Student_5                     8
#
#    Average Term Test Marks
# 0                     15.0
# 1                     15.5
# 2                     17.5
# 3                     18.0
# 4                      6.5

# %%
import pandas as pd
import random

attendance_data = {
    'Registration Number': [f'202500{i:02d}' for i in range(1, 51)],
    'Name': [f'Student_{i}' for i in range(1, 51)],
    'Attendance Marks': [random.randint(8, 10) for _ in range(50)],
    'Term Final Marks': [random.randint(50, 100) for _ in range(50)]
}

attendance_df = pd.DataFrame(attendance_data)

attendance_df.to_csv('attendance_term_final_marks.csv', index=False)

attendance_df = pd.read_csv('attendance_term_final_marks.csv')
attendance_df
# Out:
#     Registration Number        Name  Attendance Marks  Term Final Marks
# 0              20250001   Student_1                10                88
# 1              20250002   Student_2                10                98
# 2              20250003   Student_3                 9                54
# 3              20250004   Student_4                 8                50
# 4              20250005   Student_5                 9                52
# 5              20250006   Student_6                 8                73
# 6              20250007   Student_7                 9                89
# 7              20250008   Student_8                 9                57
# 8              20250009   Student_9                 8                80
# 9              20250010  Student_10                 8                77
# 10             20250011  Student_11                10                58
# 11             20250012  Student_12                 9                79
# ...

# %%
# Convert 'Registration Number' to a consistent data type (e.g., string) in both DataFrames before merging.
merged_df['Registration Number'] = merged_df['Registration Number'].astype(str)
attendance_df['Registration Number'] = attendance_df['Registration Number'].astype(str)

final_df= pd.merge(merged_df, attendance_df, on=['Registration Number', 'Name'])

final_df['Final Marks'] = (final_df['Term Final Marks'] * 0.7) + final_df['Average Term Test Marks'] + final_df['Attendance Marks']

print(final_df.head())
# Out:
#   Registration Number       Name  Best Term Test Marks  \
# 0            20250001  Student_1                    17
# 1            20250002  Student_2                    17
# 2            20250003  Student_3                    20
# 3            20250004  Student_4                    19
# 4            20250005  Student_5                     8
#
#    Average Term Test Marks  Attendance Marks  Term Final Marks  Final Marks
# 0                     15.0                10                88         86.6
# 1                     15.5                10                98         94.1
# 2                     17.5                 9                54         64.3
# 3                     18.0                 8                50         61.0
# 4                      6.5                 9                52         51.9

# %%
final_df.to_csv('final result.csv', index=False)

print("The 'final result.csv' file has been saved successfully!")
# Out:
# The 'final result.csv' file has been saved successfully!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


X = final_df[['Final Marks']]

# Standardizing the data (optional but helps with clustering performance)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Finding the optimal number of clusters using the Elbow method
inertia = []
K_range = range(2, 6)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plot the Elbow method graph
plt.figure(figsize=(8, 5))
plt.plot(K_range, inertia, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal K")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans


X = final_df[['Final Marks']]


kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
final_df['Cluster'] = kmeans.fit_predict(X)


cluster_order = final_df.groupby('Cluster')['Final Marks'].mean().sort_values().index

cluster_mapping = {cluster_order[i]: i for i in range(len(cluster_order))}
final_df['Cluster'] = final_df['Cluster'].map(cluster_mapping)

# Plotting
plt.figure(figsize=(10, 6))
sns.scatterplot(x=final_df.index, y=final_df['Final Marks'], hue=final_df['Cluster'], palette='viridis', s=200)
plt.xlabel("Student Index")
plt.ylabel("Final Marks")
plt.title("K-Means Clustering of Final Marks")
plt.legend(title="Cluster", loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()
